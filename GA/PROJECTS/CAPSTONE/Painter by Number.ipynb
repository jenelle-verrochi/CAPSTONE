# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/Users/jenelleverrochi/GA/PROJECTS/CAPSTONE'

# %%
train = pd.read_csv('/Users/jenelleverrochi/Desktop/DSI/painter_train_info.csv')

# %%
train.shape
# Out:
# (79433, 6)

# %%
train.head()
# Out:
#      filename                            artist  \
# 0  102257.jpg  5b39c876740bfc1cfaf544721c43cac3
# 1   75232.jpg  5b39c876740bfc1cfaf544721c43cac3
# 2   29855.jpg  96e5bc98488ed589b9bf17ad9fd09371
# 3   62252.jpg  5b39c876740bfc1cfaf544721c43cac3
# 4   63861.jpg  5b39c876740bfc1cfaf544721c43cac3
#
#                                          title                 style  \
# 0                                        Uriel  Color Field Painting
# 1                        Vir Heroicus Sublimis  Color Field Painting
# 2  Night March of a Hundred Demons (left half)              Yamato-e
# 3   Whoâ€™s Afraid of Red,  Yellow and Blue II  Color Field Painting
# 4                                Black Fire I   Color Field Painting
#
#                    genre  date
# 0               abstract  1955
# 1               abstract  1950
# 2  mythological painting   NaN
# 3               abstract   NaN
# 4               abstract  1963

# %%
train.date.value_counts()
# Out:
# 1910      781
# 1913      716
# 1912      678
# 1900      661
# 1890      627
# 1915      601
# 1920      599
# 1907      587
# 1895      583
# 1908      574
# 1914      572
# 1917      548
# 1911      547
# 1885      545
# 1905      540
# 1880      537
# 1902      528
# 1916      517
# 1918      508
# 1909      498
# 1906      493
# 1923      468
# 1888      464
# 1919      458
# 1903      457
# 1930      453
# 1899      440
# 1882      438
# 1934      437
# 1901      431
#          ...
# Oct-76      1
# 1315        1
# 1321        1
# 1297        1
# Jan-20      1
# 1318        1
# Apr-35      1
# 1270        1
# 1412        1
# Mar-63      1
# Jan-47      1
# 1711        1
# Jul-19      1
# 1307        1
# Sep-33      1
# 1334        1
# 1372        1
# Jan-60      1
# Apr-93      1
# 1446        1
# Sep-25      1
# 930         1
# 1319        1
# Feb-40      1
# 1108        1
# 1302        1
# ific        1
# rver        1
# 1205        1
# Nov-49      1
# ...

# %%
len(train.artist.unique())
# Out:
# 1584

# %%
len(train['style'].unique())
# Out:
# 136

# %%
len(train['genre'].unique())
# Out:
# 43

# %%
genre_dummy = pd.get_dummies(train['genre'])

# %%
g = pd.concat((genre_dummy, train['date']), axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

% matplotlib inline

# %%
g.dropna(inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(g.corr(), annot=True)
